# %%
import pandas as pd
import numpy as np
PATH = "./2016/Week 8 Feedback (2016, incomplete) - results.csv"
PATH_2017 = "./2017/Student Feedback Surveys-Superview.csv"

# %%
df = pd.read_csv(PATH)
df_2017 = pd.read_csv(PATH_2017)

df["Week"] = [8] * 65

# %%
df
# Out:
#                                    #  \
# 0   00b836bda84e6bdbe780af97e249e59f
# 1   39dde6dc0e1e375845d756fc7e39fc5f
# 2   5e56b9de91670b308cb98dd2848b8739
# 3   641081d05785b47a0f17448625da0d49
# 4   c29bdd4f5678d78b450f4494e0f53c8c
# 5   9030d8a662b39b519b2b685834413d66
# 6   1c07190c7caa72bf6b59cea48e1a4a97
# 7   27a63d6c24710feb52c0cfdef7e01175
# 8   b47b95f84547d8347119de1da5faa46d
# 9   828fafa477484f61d2ca5930fe99ad46
# 10  7d70f1e30217d867f3c0f961462d8ae8
# 11  65bd071ab808290560e7d11c09f56796
# 12  d66976d012b4c8a5c708f1a438605488
# 13  9db748a8e0d5789cb3a5fcb27fc59083
# 14  5ee2a5d8e87fd5790906f7b004963e14
# 15  9826290f1bf2fd4c105857e2af933ffe
# 16  ea85e7c699751b5993776ef16db0b1d9
# 17  58cb61ce774b116d87e3888d4c1babf1
# 18  a08ef61cfa87d1ba00c691de4a55f4c2
# 19  630fd265cdb8308b60b4b59351690f0a
# 20  2f7303a7ac0943b341d02678b085688e
# 21  785568c94d73aa0fad4493ee79fa3974
# 22  fe02b118aea0ef15ccd06e6f7e6209f4
# 23  6e2c750a71613e3fd7d5f425320cc750
# ...

# %%
df["How likely is it that you would recommend the Make School Summer Academy to a friend?"].value_counts(dropna=False)
# Out:
# 10    28
# 9     14
# 8     11
# 7      6
# 5      2
# 3      2
# 6      1
# 4      1
# Name: How likely is it that you would recommend the Make School Summer Academy to a friend?, dtype: int64

# %%
## Rename the tracks so it can be concatinated to whole data
old_track_values = df["track"].value_counts().keys().tolist()
new_track_value = ['Apps', 'Games', 'Intro', 'VR', 'Apps', 'Games']
print(values)
df = df.replace(old_track_values, new_track_value)
# Out:
# ['summerApps', 'summerGames', 'summerIntro', 'summerVR', 'summerApps (4-week)', 'summerGames (4-week)']

# %%
## Change the locations to 2 letter version
old_location_values = df["location"].value_counts().keys().tolist()
two_letter_location = ['SF', 'SV', 'NY', 'SG', 'LA']
print(old_location_values)

df.replace(old_location_values, two_letter_location)
# Out:
# ['San Francisco', 'Sunnyvale', 'New York', 'Singapore', 'Los Angeles']
#                                    #  \
# 0   00b836bda84e6bdbe780af97e249e59f
# 1   39dde6dc0e1e375845d756fc7e39fc5f
# 2   5e56b9de91670b308cb98dd2848b8739
# 3   641081d05785b47a0f17448625da0d49
# 4   c29bdd4f5678d78b450f4494e0f53c8c
# 5   9030d8a662b39b519b2b685834413d66
# 6   1c07190c7caa72bf6b59cea48e1a4a97
# 7   27a63d6c24710feb52c0cfdef7e01175
# 8   b47b95f84547d8347119de1da5faa46d
# 9   828fafa477484f61d2ca5930fe99ad46
# 10  7d70f1e30217d867f3c0f961462d8ae8
# 11  65bd071ab808290560e7d11c09f56796
# 12  d66976d012b4c8a5c708f1a438605488
# 13  9db748a8e0d5789cb3a5fcb27fc59083
# 14  5ee2a5d8e87fd5790906f7b004963e14
# 15  9826290f1bf2fd4c105857e2af933ffe
# 16  ea85e7c699751b5993776ef16db0b1d9
# 17  58cb61ce774b116d87e3888d4c1babf1
# 18  a08ef61cfa87d1ba00c691de4a55f4c2
# 19  630fd265cdb8308b60b4b59351690f0a
# 20  2f7303a7ac0943b341d02678b085688e
# 21  785568c94d73aa0fad4493ee79fa3974
# ...

# %%
df
# Out:
#                                    #  \
# 0   00b836bda84e6bdbe780af97e249e59f
# 1   39dde6dc0e1e375845d756fc7e39fc5f
# 2   5e56b9de91670b308cb98dd2848b8739
# 3   641081d05785b47a0f17448625da0d49
# 4   c29bdd4f5678d78b450f4494e0f53c8c
# 5   9030d8a662b39b519b2b685834413d66
# 6   1c07190c7caa72bf6b59cea48e1a4a97
# 7   27a63d6c24710feb52c0cfdef7e01175
# 8   b47b95f84547d8347119de1da5faa46d
# 9   828fafa477484f61d2ca5930fe99ad46
# 10  7d70f1e30217d867f3c0f961462d8ae8
# 11  65bd071ab808290560e7d11c09f56796
# 12  d66976d012b4c8a5c708f1a438605488
# 13  9db748a8e0d5789cb3a5fcb27fc59083
# 14  5ee2a5d8e87fd5790906f7b004963e14
# 15  9826290f1bf2fd4c105857e2af933ffe
# 16  ea85e7c699751b5993776ef16db0b1d9
# 17  58cb61ce774b116d87e3888d4c1babf1
# 18  a08ef61cfa87d1ba00c691de4a55f4c2
# 19  630fd265cdb8308b60b4b59351690f0a
# 20  2f7303a7ac0943b341d02678b085688e
# 21  785568c94d73aa0fad4493ee79fa3974
# 22  fe02b118aea0ef15ccd06e6f7e6209f4
# 23  6e2c750a71613e3fd7d5f425320cc750
# ...

# %%
df["location"].unique()
# Out:
# array(['New York', 'San Francisco', 'Sunnyvale', 'Singapore',
#        'Los Angeles'], dtype=object)

# %%
# frame = frame[['column I want first', 'column I want second'...etc.]]

# %%
df["location"].value_counts(dropna=False)
# Out:
# San Francisco    29
# Sunnyvale        16
# New York         12
# Singapore         5
# Los Angeles       3
# Name: location, dtype: int64
